# %% [markdown]
# Goal: show our FedFB still outperforms FFL via FedAvg if they leaked the same amount of information.
#
# Based on: https://github.com/OpenMined/PyDP/blob/dev/examples/laplace_demo/laplace.ipynb

# %%
import pydp as dp # by convention our package is to be imported as dp (dp for Differential Privacy!)
from pydp.algorithms.laplacian import BoundedSum, BoundedMean, Count, Max
import pandas as pd
import statistics 
import numpy as np
import matplotlib.pyplot as plt

import sys, os
working_dir = '.'
sys.path.insert(1, os.path.join(working_dir, 'FedFB'))
os.environ["PYTHONPATH"] = os.path.join(working_dir, 'FedFB')

# %%
from DP_run_private import *

# %%
sim_dp('fedfb', 'multilayer perceptron', 'synthetic', ε = 0.1)
# Out:
# --------------------------------Hyperparameter selection--------------------------------
# --------------------------------Seed:0--------------------------------
# == Status ==
# Memory usage on this node: 14.5/16.0 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 80.000: None | Iter 20.000: None | Iter 5.000: None
# Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/8.7 GiB heap, 0.0/4.35 GiB objects
# Result logdir: /Users/zengyuchen/ray_results/trainable_2021-09-26_02-11-51
# Number of trials: 16/24 (16 PENDING)
# +-----------------------+----------+-------+---------+-------+
# | Trial name            | status   | loc   |   alpha |    lr |
# |-----------------------+----------+-------+---------+-------|
# ...

# %%
sim_dp('fedfb', 'multilayer perceptron', 'synthetic', ε = 0.5)
# Out:
# --------------------------------Hyperparameter selection--------------------------------
# --------------------------------Seed:0--------------------------------
# == Status ==
# Memory usage on this node: 14.5/16.0 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 80.000: None | Iter 20.000: None | Iter 5.000: None
# Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/8.7 GiB heap, 0.0/4.35 GiB objects
# Result logdir: /Users/zengyuchen/ray_results/trainable_2021-09-26_02-07-12
# Number of trials: 16/24 (16 PENDING)
# +-----------------------+----------+-------+---------+-------+
# | Trial name            | status   | loc   |   alpha |    lr |
# |-----------------------+----------+-------+---------+-------|
# ...

# %%
sim_dp('fedfb', 'multilayer perceptron', 'synthetic', ε = 1)
# Out:
# --------------------------------Hyperparameter selection--------------------------------
# --------------------------------Seed:0--------------------------------
# == Status ==
# Memory usage on this node: 14.7/16.0 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 80.000: None | Iter 20.000: None | Iter 5.000: None
# Resources requested: 4.0/8 CPUs, 0/0 GPUs, 0.0/8.62 GiB heap, 0.0/4.31 GiB objects
# Result logdir: /Users/zengyuchen/ray_results/trainable_2021-09-27_19-33-38
# Number of trials: 16/24 (15 PENDING, 1 RUNNING)
# +-----------------------+----------+-------+---------+-------+
# | Trial name            | status   | loc   |   alpha |    lr |
# ...

# %%
sim_dp('fedfb', 'multilayer perceptron', 'synthetic', ε = 10)
# Out:
# --------------------------------Hyperparameter selection--------------------------------
# --------------------------------Seed:0--------------------------------
# == Status ==
# Memory usage on this node: 14.6/16.0 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 80.000: None | Iter 20.000: None | Iter 5.000: None
# Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/8.7 GiB heap, 0.0/4.35 GiB objects
# Result logdir: /Users/zengyuchen/ray_results/trainable_2021-09-26_02-16-49
# Number of trials: 16/24 (16 PENDING)
# +-----------------------+----------+-------+---------+-------+
# | Trial name            | status   | loc   |   alpha |    lr |
# |-----------------------+----------+-------+---------+-------|
# ...

# %%
sim_dp('fflfb', 'multilayer perceptron', 'synthetic', ε = 0.1)
# Out:
# --------------------------------Hyperparameter selection--------------------------------
# --------------------------------Seed:0--------------------------------
# == Status ==
# Memory usage on this node: 14.5/16.0 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 80.000: None | Iter 20.000: None | Iter 5.000: None
# Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/8.7 GiB heap, 0.0/4.35 GiB objects
# Result logdir: /Users/zengyuchen/ray_results/trainable_2021-09-26_02-21-37
# Number of trials: 8/8 (8 PENDING)
# +-----------------------+----------+-------+---------+
# | Trial name            | status   | loc   |   alpha |
# |-----------------------+----------+-------+---------|
# ...

# %%
sim_dp('fflfb', 'multilayer perceptron', 'synthetic', ε = 0.5)
# Out:
# --------------------------------Hyperparameter selection--------------------------------
# --------------------------------Seed:0--------------------------------
# == Status ==
# Memory usage on this node: 14.5/16.0 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 80.000: None | Iter 20.000: None | Iter 5.000: None
# Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/8.7 GiB heap, 0.0/4.35 GiB objects
# Result logdir: /Users/zengyuchen/ray_results/trainable_2021-09-26_02-26-55
# Number of trials: 8/8 (8 PENDING)
# +-----------------------+----------+-------+---------+
# | Trial name            | status   | loc   |   alpha |
# |-----------------------+----------+-------+---------|
# ...

# %%
sim_dp('fflfb', 'multilayer perceptron', 'synthetic', ε = 1)
# Out:
# --------------------------------Hyperparameter selection--------------------------------
# --------------------------------Seed:0--------------------------------
# == Status ==
# Memory usage on this node: 14.7/16.0 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 80.000: None | Iter 20.000: None | Iter 5.000: None
# Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/8.62 GiB heap, 0.0/4.31 GiB objects
# Result logdir: /Users/zengyuchen/ray_results/trainable_2021-09-27_19-39-02
# Number of trials: 8/8 (8 PENDING)
# +-----------------------+----------+-------+---------+
# | Trial name            | status   | loc   |   alpha |
# |-----------------------+----------+-------+---------|
# ...

# %%
sim_dp('fflfb', 'multilayer perceptron', 'synthetic', ε = 10)
# Out:
# --------------------------------Hyperparameter selection--------------------------------
# --------------------------------Seed:0--------------------------------
# == Status ==
# Memory usage on this node: 14.5/16.0 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 80.000: None | Iter 20.000: None | Iter 5.000: None
# Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/8.7 GiB heap, 0.0/4.35 GiB objects
# Result logdir: /Users/zengyuchen/ray_results/trainable_2021-09-26_02-31-51
# Number of trials: 8/8 (8 PENDING)
# +-----------------------+----------+-------+---------+
# | Trial name            | status   | loc   |   alpha |
# |-----------------------+----------+-------+---------|
# ...
