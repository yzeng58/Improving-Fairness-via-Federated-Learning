# %% [markdown]
# Goal: evluate the performance of FedFB under different data heterogeneity.

# %%
import sys, os
working_dir = '.'
sys.path.insert(1, os.path.join(working_dir, 'FedFB'))
os.environ["PYTHONPATH"] = os.path.join(working_dir, 'FedFB')
import numpy as np

# %%
from DP_run_custom import *
from DP_load_dataset import dataSplit, dataGenerate

# %%
info1 = dataGenerate(seed = 123, test_samples = 1500, train_samples = 3500, client_split = ((.33, .33), (.33, .33), (.34, .34)))

info3 = dataGenerate(seed = 123, test_samples = 1500, train_samples = 3500, client_split = ((.7, .1), (1., .8), (.2, .1)))

# %%
sim_dp('fedavg', 'multilayer perceptron', info1)
# Out:
# --------------------------------Hyperparameter selection--------------------------------
# --------------------------------Seed:0--------------------------------
# 2021-09-24 00:47:26,074	INFO services.py:1263 -- View the Ray dashboard at http://127.0.0.1:8265
# 2021-09-24 00:47:28,365	WARNING function_runner.py:558 -- Function checkpointing is disabled. This may result in unexpected behavior when using checkpointing features or certain schedulers. To enable, set the train function arguments to be `func(config, checkpoint_dir=None)`.
# == Status ==
# Memory usage on this node: 15.2/16.0 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 80.000: None | Iter 20.000: None | Iter 5.000: None
# ...

# %%
sim_dp('uflfb', 'multilayer perceptron', info1)
# Out:
# --------------------------------Hyperparameter selection--------------------------------
# --------------------------------Seed:0--------------------------------
# == Status ==<br>Memory usage on this node: 15.1/16.0 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.<br>Using FIFO scheduling algorithm.<br>Resources requested: 4.0/8 CPUs, 0/0 GPUs, 0.0/8.85 GiB heap, 0.0/4.43 GiB objects<br>Result logdir: /Users/zengyuchen/ray_results/trainable_2021-09-24_00-49-10<br>Number of trials: 8/8 (7 PENDING, 1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc  </th><th style="text-align: right;">  alpha</th></tr>
# </thead>
# <tbody>
# ...

# %%
sim_dp('fflfb', 'multilayer perceptron', info1, resources_per_trial = {'cpu':6})
# Out:
# --------------------------------Hyperparameter selection--------------------------------
# --------------------------------Seed:0--------------------------------
# 2021-09-24 01:15:29,240	INFO services.py:1263 -- View the Ray dashboard at http://127.0.0.1:8265
# 2021-09-24 01:15:30,551	WARNING function_runner.py:558 -- Function checkpointing is disabled. This may result in unexpected behavior when using checkpointing features or certain schedulers. To enable, set the train function arguments to be `func(config, checkpoint_dir=None)`.
# == Status ==
# Memory usage on this node: 15.2/16.0 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 80.000: None | Iter 20.000: None | Iter 5.000: None
# ...

# %%
sim_dp('cflfb', 'multilayer perceptron', info1, resources_per_trial = {'cpu':6})
# Out:
# --------------------------------Hyperparameter selection--------------------------------
# --------------------------------Seed:0--------------------------------
# 2021-09-24 01:37:11,821	INFO services.py:1263 -- View the Ray dashboard at http://127.0.0.1:8265
# 2021-09-24 01:37:13,122	WARNING function_runner.py:558 -- Function checkpointing is disabled. This may result in unexpected behavior when using checkpointing features or certain schedulers. To enable, set the train function arguments to be `func(config, checkpoint_dir=None)`.
# == Status ==
# Memory usage on this node: 15.1/16.0 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 50.000: None
# ...

# %%
sim_dp('fedfb', 'multilayer perceptron', info1, resources_per_trial = {'cpu':5})
# Out:
# --------------------------------Hyperparameter selection--------------------------------
# --------------------------------Seed:0--------------------------------
# == Status ==
# Memory usage on this node: 15.2/16.0 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 80.000: None | Iter 20.000: None | Iter 5.000: None
# Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/8.85 GiB heap, 0.0/4.42 GiB objects
# Result logdir: /Users/zengyuchen/ray_results/trainable_2021-09-24_01-49-38
# Number of trials: 16/24 (16 PENDING)
# +-----------------------+----------+-------+---------+-------+
# | Trial name            | status   | loc   |   alpha |    lr |
# |-----------------------+----------+-------+---------+-------|
# ...

# %%
sim_dp('fedavg', 'multilayer perceptron', info3, resources_per_trial = {'cpu':5})
# Out:
# --------------------------------Hyperparameter selection--------------------------------
# --------------------------------Seed:0--------------------------------
# == Status ==
# Memory usage on this node: 15.1/16.0 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 80.000: None | Iter 20.000: None | Iter 5.000: None
# Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/8.85 GiB heap, 0.0/4.42 GiB objects
# Result logdir: /Users/zengyuchen/ray_results/trainable_2021-09-24_02-24-56
# Number of trials: 5/5 (5 PENDING)
# +-----------------------+----------+-------+-------+
# | Trial name            | status   | loc   |    lr |
# |-----------------------+----------+-------+-------|
# ...

# %%
sim_dp('uflfb', 'multilayer perceptron', info3, resources_per_trial = {'cpu':5})
# Out:
# --------------------------------Hyperparameter selection--------------------------------
# --------------------------------Seed:0--------------------------------
# == Status ==<br>Memory usage on this node: 15.1/16.0 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/8.85 GiB heap, 0.0/4.42 GiB objects<br>Result logdir: /Users/zengyuchen/ray_results/trainable_2021-09-24_02-27-11<br>Number of trials: 8/8 (8 PENDING)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc  </th><th style="text-align: right;">  alpha</th></tr>
# </thead>
# <tbody>
# <tr><td>trainable_d4e7f_00000</td><td>PENDING </td><td>     </td><td style="text-align: right;">  0.001</td></tr>
# ...

# %%
sim_dp('fflfb', 'multilayer perceptron', info3, resources_per_trial = {'cpu':5})
# Out:
# --------------------------------Hyperparameter selection--------------------------------
# --------------------------------Seed:0--------------------------------
# == Status ==
# Memory usage on this node: 15.1/16.0 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 80.000: None | Iter 20.000: None | Iter 5.000: None
# Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/8.85 GiB heap, 0.0/4.42 GiB objects
# Result logdir: /Users/zengyuchen/ray_results/trainable_2021-09-24_02-34-26
# Number of trials: 8/8 (8 PENDING)
# +-----------------------+----------+-------+---------+
# | Trial name            | status   | loc   |   alpha |
# |-----------------------+----------+-------+---------|
# ...

# %%
sim_dp('cflfb', 'multilayer perceptron', info3, resources_per_trial = {'cpu':5})
# Out:
# --------------------------------Hyperparameter selection--------------------------------
# --------------------------------Seed:0--------------------------------
# == Status ==
# Memory usage on this node: 15.1/16.0 GiB: ***LOW MEMORY*** less than 10% of the memory on this node is available for use. This can cause unexpected crashes. Consider reducing the memory used by your application or reducing the Ray object store size by setting `object_store_memory` when calling `ray.init`.
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 50.000: None
# Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/8.85 GiB heap, 0.0/4.42 GiB objects
# Result logdir: /Users/zengyuchen/ray_results/trainable_2021-09-24_02-41-06
# Number of trials: 16/24 (16 PENDING)
# +-----------------------+----------+-------+---------+-------+
# | Trial name            | status   | loc   |   alpha |    lr |
# |-----------------------+----------+-------+---------+-------|
# ...

# %%
sim_dp('fedfb', 'multilayer perceptron', info3, resources_per_trial = {'cpu':4})
# Out:
# --------------------------------Hyperparameter selection--------------------------------
# --------------------------------Seed:0--------------------------------
# 2021-09-24 16:04:31,664	INFO services.py:1265 -- View the Ray dashboard at http://127.0.0.1:8265
# 2021-09-24 16:04:34,642	WARNING function_runner.py:559 -- Function checkpointing is disabled. This may result in unexpected behavior when using checkpointing features or certain schedulers. To enable, set the train function arguments to be `func(config, checkpoint_dir=None)`.
# == Status ==
# Memory usage on this node: 6.3/8.0 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 80.000: None | Iter 20.000: None | Iter 5.000: None
# Resources requested: 4.0/4 CPUs, 0/0 GPUs, 0.0/2.43 GiB heap, 0.0/1.21 GiB objects
# Result logdir: /Users/cengyuchen/ray_results/trainable_2021-09-24_16-04-34
# Number of trials: 16/24 (15 PENDING, 1 RUNNING)
# +-----------------------+----------+-------+---------+-------+
# ...
